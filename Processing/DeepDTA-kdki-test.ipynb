# %%
import os
os.chdir('../')

import DeepPurpose.DTI as models
from DeepPurpose.utils import *
from DeepPurpose.dataset import *
import Processing.dataset_filter as processors
import gradio
import Processing.testing as testing

if not os.path.exists('./result/DeepDTA'):
    os.makedirs('./result/DeepDTA')

    # def DTI_pred(drug, target):
#     X_pred = data_process(X_drug = [drug], X_target = [target], y = [0],
#                                 drug_encoding = 'CNN', target_encoding = 'CNN', 
#                                 split_method='no_split')
#     y_pred = model.predict(X_pred)
#     return str(y_pred[0])

# gradio.Interface(DTI_pred, 
#                  [gradio.inputs.Textbox(lines = 5, label = "Drug SMILES"),
#                   gradio.inputs.Textbox(lines = 5, label = "Target Sequence")], 
#                  gradio.outputs.Textbox(label = "Predicted Affinity")).launch(share=True)

# %%
df = pd.read_csv('./data/r1/title_r1_test45021.csv', sep = ',', error_bad_lines=False)
X_drug, X_target, y = df['Drug'].values, df['Target'].values, df['Label'].values

# %%
testing.batch_predict('./result/DeepDTA/r1/model_r1_0.625k_100epochs', 'r1 0.625k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r1/model_r1_1.25k_100epochs', 'r1 1.25k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r1/model_r1_2.5k_100epochs', 'r1 2.5k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r1/model_r1_5k_100epochs', 'r1 5k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r1/model_r1_10k_100epochs', 'r1 10k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r1/model_r1_20k_100epochs', 'r1 20k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r1/model_r1_40k_100epochs', 'r1 40k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r1/model_r1_80k_100epochs', 'r1 80k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r1/model_r1_160k_100epochs', 'r1 160k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r1/model_r1_320k_100epochs', 'r1 320k', X_drug, X_target, y)
# Out:
# Loading pre-trained model from path: ./result/DeepDTA/r1/model_r1_0.625k_100epochs
# Drug Target Interaction Prediction Mode...
# in total: 45021 drug-target pairs
# encoding drug...
# unique drugs: 39401
# encoding protein...
# unique target sequence: 2469
# splitting dataset...
# do not do train/test split on the data for already splitted data
# predicting...
# [r1 0.625k] Testing MSE: 2.221708274752166 , Pearson Correlation: 0.3292138058280336 with p-value: 0.00E+00 , Concordance Index: 0.6046968609012277
# --- Finish Testing r1 0.625k ---
# Loading pre-trained model from path: ./result/DeepDTA/r1/model_r1_1.25k_100epochs
# Drug Target Interaction Prediction Mode...
# in total: 45021 drug-target pairs
# encoding drug...
# unique drugs: 39401
# encoding protein...
# unique target sequence: 2469
# splitting dataset...
# do not do train/test split on the data for already splitted data
# predicting...
# ...

# %%
df = pd.read_csv('./data/r2/title_r2_test45021.csv', sep = ',', error_bad_lines=False)
X_drug, X_target, y = df['Drug'].values, df['Target'].values, df['Label'].values

# %%
testing.batch_predict('./result/DeepDTA/r2/model_r2_0.625k_100epochs', 'r2 0.625k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r2/model_r2_1.25k_100epochs', 'r2 1.25k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r2/model_r2_2.5k_100epochs', 'r2 2.5k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r2/model_r2_5k_100epochs', 'r2 5k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r2/model_r2_10k_100epochs', 'r2 10k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r2/model_r2_20k_100epochs', 'r2 20k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r2/model_r2_40k_100epochs', 'r2 40k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r2/model_r2_80k_100epochs', 'r2 80k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r2/model_r2_160k_100epochs', 'r2 160k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r2/model_r2_320k_100epochs', 'r2 320k', X_drug, X_target, y)
# Out:
# Loading pre-trained model from path: ./result/DeepDTA/r2/model_r2_0.625k_100epochs
# Drug Target Interaction Prediction Mode...
# in total: 45021 drug-target pairs
# encoding drug...
# unique drugs: 39272
# encoding protein...
# unique target sequence: 2413
# splitting dataset...
# do not do train/test split on the data for already splitted data
# predicting...
# [r2 0.625k] Testing MSE: 1.9693306605222467 , Pearson Correlation: 0.27885995338998315 with p-value: 0.00E+00 , Concordance Index: 0.5828144047479711
# --- Finish Testing r2 0.625k ---
# Loading pre-trained model from path: ./result/DeepDTA/r2/model_r2_1.25k_100epochs
# Drug Target Interaction Prediction Mode...
# in total: 45021 drug-target pairs
# encoding drug...
# unique drugs: 39272
# encoding protein...
# unique target sequence: 2413
# splitting dataset...
# do not do train/test split on the data for already splitted data
# predicting...
# ...

# %%
df = pd.read_csv('./data/r3/title_r3_test45021.csv', sep = ',', error_bad_lines=False)
X_drug, X_target, y = df['Drug'].values, df['Target'].values, df['Label'].values

# %%
testing.batch_predict('./result/DeepDTA/r3/model_r3_0.625k_100epochs', 'r3 0.625k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r3/model_r3_1.25k_100epochs', 'r3 1.25k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r3/model_r3_2.5k_100epochs', 'r3 2.5k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r3/model_r3_5k_100epochs', 'r3 5k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r3/model_r3_10k_100epochs', 'r3 10k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r3/model_r3_20k_100epochs', 'r3 20k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r3/model_r3_40k_100epochs', 'r3 40k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r3/model_r3_80k_100epochs', 'r3 80k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r3/model_r3_160k_100epochs', 'r3 160k', X_drug, X_target, y)
testing.batch_predict('./result/DeepDTA/r3/model_r3_320k_100epochs', 'r3 320k', X_drug, X_target, y)
# Out:
# Loading pre-trained model from path: ./result/DeepDTA/r3/model_r3_0.625k_100epochs
# Drug Target Interaction Prediction Mode...
# in total: 45021 drug-target pairs
# encoding drug...
# unique drugs: 39404
# encoding protein...
# unique target sequence: 2422
# splitting dataset...
# do not do train/test split on the data for already splitted data
# predicting...
# [r3 0.625k] Testing MSE: 2.0215674449799166 , Pearson Correlation: 0.22960617511322434 with p-value: 0.00E+00 , Concordance Index: 0.5715036062146492
# --- Finish Testing r3 0.625k ---
# Loading pre-trained model from path: ./result/DeepDTA/r3/model_r3_1.25k_100epochs
# Drug Target Interaction Prediction Mode...
# in total: 45021 drug-target pairs
# encoding drug...
# unique drugs: 39404
# encoding protein...
# unique target sequence: 2422
# splitting dataset...
# do not do train/test split on the data for already splitted data
# predicting...
# ...
